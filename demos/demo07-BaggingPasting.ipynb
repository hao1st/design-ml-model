# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
insurance_data = pd.read_csv('dataset/insurance.csv')

insurance_data.sample(10)
# Out:
#       age     sex    bmi  children smoker     region      charges
# 1128   34    male  32.80         1     no  southwest  14358.36437
# 39     60    male  39.90         0    yes  southwest  48173.36100
# 138    54  female  31.90         3     no  southeast  27322.73386
# 697    41    male  35.75         1    yes  southeast  40273.64550
# 164    37    male  29.64         0     no  northwest   5028.14660
# 700    21  female  34.87         0     no  southeast   2020.55230
# 93     35    male  34.77         2     no  northwest   5729.00530
# 674    44  female  43.89         2    yes  southeast  46200.98510
# 336    60    male  25.74         0     no  southeast  12142.57860
# 153    42  female  23.37         0    yes  northeast  19964.74630

# %%
insurance_data.shape
# Out:
# (1338, 7)

# %%
insurance_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from sklearn import preprocessing

label_encoding = preprocessing.LabelEncoder()

#insurance_data['sex'] = label_encoding.fit_transform(insurance_data['sex'].astype(str))
#insurance_data['smoker'] = label_encoding.fit_transform(insurance_data['smoker'].astype(str))
insurance_data['region'] = label_encoding.fit_transform(insurance_data['region'].astype(str))

insurance_data.sample(10)
# Out:
#       age     sex     bmi  children smoker  region      charges
# 185    36    male  41.895         3    yes       0  43753.33705
# 129    38    male  34.700         2     no       3   6082.40500
# 1012   61  female  33.330         4     no       2  36580.28216
# 784    31  female  29.260         1     no       2   4350.51440
# 1155   36  female  22.135         3     no       0   7228.21565
# 770    61    male  36.100         3     no       3  27941.28758
# 586    21    male  20.235         3     no       0   3861.20965
# 1140   50    male  37.070         1     no       2   9048.02730
# 46     18  female  38.665         2     no       0   3393.35635
# 964    52    male  36.765         2     no       1  26467.09737

# %%
label_encoding.classes_
# Out:
# array(['northeast', 'northwest', 'southeast', 'southwest'], dtype=object)

# %%
insurance_data = pd.get_dummies(insurance_data, columns=['sex',
                                                         'smoker'])

insurance_data.sample(10)
# Out:
#       age     bmi  children  region      charges  sex_female  sex_male  \
# 279    51  21.560         1       2   9855.13140        True     False
# 873    43  30.100         1       3   6849.02600       False      True
# 412    26  17.195         2       0  14455.64405        True     False
# 71     31  28.500         5       0   6799.45800       False      True
# 1173   38  29.260         2       1   6457.84340       False      True
# 654    59  35.200         0       2  12244.53100        True     False
# 1297   28  26.510         2       2   4340.44090        True     False
# 1116   41  29.640         5       0   9222.40260       False      True
# 519    31  30.875         0       0   3857.75925       False      True
# 304    57  38.000         2       3  12646.20700        True     False
#
#       smoker_no  smoker_yes
# 279        True       False
# 873        True       False
# 412       False        True
# 71         True       False
# 1173       True       False
# 654        True       False
# 1297       True       False
# 1116       True       False
# 519        True       False
# 304        True       False

# %%
insurance_data.head()
# Out:
#    age     bmi  children  region      charges  sex_female  sex_male  \
# 0   19  27.900         0       3  16884.92400        True     False
# 1   18  33.770         1       2   1725.55230       False      True
# 2   28  33.000         3       2   4449.46200       False      True
# 3   33  22.705         0       1  21984.47061       False      True
# 4   32  28.880         0       1   3866.85520       False      True
#
#    smoker_no  smoker_yes
# 0      False        True
# 1       True       False
# 2       True       False
# 3       True       False
# 4       True       False

# %%
insurance_data.to_csv('dataset/insurance_processed.csv', index=False)

# %%
# !ls dataset
# Out:
# Advertising.csv           PimaIndians_processed.csv insurance.csv
# PimaIndians.csv           driver_dataset.csv        insurance_processed.csv

# %% [markdown]
# ### Loading Dataset

# %%
insurance_data = pd.read_csv('dataset/insurance_processed.csv')

insurance_data.sample(10)
# Out:
#       age     bmi  children  region      charges  sex_female  sex_male  \
# 56     58  31.825         2       0  13607.36875        True     False
# 161    18  36.850         0       2  36149.48350        True     False
# 1335   18  36.850         0       2   1629.83350        True     False
# 781    18  41.140         0       2   1146.79660       False      True
# 195    19  30.590         0       1   1639.56310       False      True
# 726    41  28.405         1       1   6664.68595       False      True
# 1091   55  29.830         0       0  11286.53870        True     False
# 841    59  24.700         0       0  12323.93600       False      True
# 1047   22  52.580         1       2  44501.39820       False      True
# 1166   57  40.370         0       2  10982.50130       False      True
#
#       smoker_no  smoker_yes
# 56         True       False
# 161       False        True
# 1335       True       False
# 781        True       False
# 195        True       False
# 726        True       False
# 1091       True       False
# 841        True       False
# 1047      False        True
# 1166       True       False

# %%
insurance_data.shape
# Out:
# (1338, 9)

# %%
X = insurance_data.drop('charges', axis=1)

Y = insurance_data['charges']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
x_train.shape, y_train.shape
# Out:
# ((1070, 8), (1070,))

# %%
x_test.shape, y_test.shape
# Out:
# ((268, 8), (268,))

# %% [markdown]
# ### Bagging Regressor
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.BaggingRegressor.html

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor

# %%
bag_reg = BaggingRegressor(DecisionTreeRegressor(), 
                           n_estimators=500,
                           bootstrap=True,
                           max_samples=0.8,
                           n_jobs=-1,
                           oob_score=True)

bag_reg.fit(x_train, y_train)
# Out:
# BaggingRegressor(estimator=DecisionTreeRegressor(), max_samples=0.8,
#                  n_estimators=500, n_jobs=-1, oob_score=True)

# %%
bag_reg.oob_score_
# Out:
# 0.8471382232834119

# %%
from sklearn.metrics import r2_score

y_pred = bag_reg.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.8400056522544609

# %%
bag_reg = BaggingRegressor(DecisionTreeRegressor(), 
                           n_estimators=500,
                           bootstrap=False,
                           max_samples=0.9,
                           n_jobs=-1)

bag_reg.fit(x_train, y_train)
# Out:
# BaggingRegressor(bootstrap=False, estimator=DecisionTreeRegressor(),
#                  max_samples=0.9, n_estimators=500, n_jobs=-1)

# %%
y_pred = bag_reg.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.7938246461844962
